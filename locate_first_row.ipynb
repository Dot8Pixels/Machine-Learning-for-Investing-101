# %%
import pandas as pd
import yfinance as yf
import seaborn as sns

# %%
# data = yf.download("BBL.BK KBANK.BK SCB.BK BAY.BK TTB.BK KKP.BK TISCO.BK SAWAD.BK MTC.BK TIDLOR.BK AMNAH.BK AEONTS.BK ASK.BK CHAYO.BK JMT.BK KTC.BK MICRO.BK MTC.BK NCAP.BK S11.BK SAK.BK THANI.BK TK.BK", 
#                     start='2018-01-01', end='2021-10-14', period='1d')

data = yf.download("BBL.BK KBANK.BK BAY.BK TTB.BK KKP.BK TISCO.BK SAWAD.BK MTC.BK TIDLOR.BK AEONTS.BK ASK.BK CHAYO.BK JMT.BK KTC.BK MICRO.BK MTC.BK NCAP.BK S11.BK SAK.BK THANI.BK TK.BK", 
                    start='2018-01-01', end='2021-10-14', period='1d')
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
data['Adj Close']
# Out:
#              AEONTS.BK     ASK.BK     BAY.BK      BBL.BK   CHAYO.BK  \
# Date
# 2018-01-03   92.578255  17.726864  35.356331  175.389221        NaN
# 2018-01-04   92.578255  17.875828  34.693398  175.389221        NaN
# 2018-01-05   93.025475  17.801344  40.438797  176.244751        NaN
# 2018-01-08   93.919960  17.726864  41.543686  177.100311        NaN
# 2018-01-09  107.337105  17.577898  40.659779  177.955856        NaN
# ...                ...        ...        ...         ...        ...
# 2021-10-06  188.250259  34.164398  32.072990  113.392334  11.047817
# 2021-10-07  192.141724  34.164398  32.566422  116.337585  11.141443
# 2021-10-08  190.682434  34.652462  32.566422  116.337585  11.047817
# 2021-10-11  189.223129  34.652462  32.319706  116.337585  10.860567
# 2021-10-12  189.709564  34.652462  32.319706  117.810219  10.860567
#
#                JMT.BK    KBANK.BK     KKP.BK     KTC.BK  MICRO.BK     MTC.BK  \
# Date
# ...

# %%
df = data['Adj Close'].copy()

# %%
df.loc[df['CHAYO.BK'].notnull()]
# Out:
#              AEONTS.BK     ASK.BK     BAY.BK      BBL.BK   CHAYO.BK  \
# Date
# 2018-03-22  161.452896  17.494516  37.566101  174.533661   1.638680
# 2018-03-23  157.874985  17.336908  37.124146  172.822525   1.980073
# 2018-03-26  162.794601  17.258102  36.903168  171.111420   2.002832
# 2018-03-27  167.714218  17.258102  36.903168  172.822525   1.866275
# 2018-03-28  166.819733  17.258102  36.240238  172.822525   1.843515
# ...                ...        ...        ...         ...        ...
# 2021-10-06  188.250259  34.164398  32.072990  113.392334  11.047817
# 2021-10-07  192.141724  34.164398  32.566422  116.337585  11.141443
# 2021-10-08  190.682434  34.652462  32.566422  116.337585  11.047817
# 2021-10-11  189.223129  34.652462  32.319706  116.337585  10.860567
# 2021-10-12  189.709564  34.652462  32.319706  117.810219  10.860567
#
#                JMT.BK    KBANK.BK     KKP.BK     KTC.BK  MICRO.BK     MTC.BK  \
# Date
# ...

# %%
df.loc[~df.isnull().sum(1).astype(bool)].iloc[0]
# Out:
# AEONTS.BK    203.582214
# ASK.BK        32.944241
# BAY.BK        34.599052
# BBL.BK       115.794579
# CHAYO.BK      14.228763
# JMT.BK        43.861530
# KBANK.BK     122.760376
# KKP.BK        54.080425
# KTC.BK        71.762711
# MICRO.BK       9.495888
# MTC.BK        62.002689
# NCAP.BK       15.500000
# S11.BK         7.050314
# SAK.BK        12.141466
# SAWAD.BK      77.804184
# THANI.BK       4.075434
# TIDLOR.BK     42.156548
# TISCO.BK      82.372490
# TK.BK          9.840178
# TTB.BK         1.126857
# Name: 2021-05-10 00:00:00, dtype: float64

# %%
df.loc[~df.isnull().sum(1).astype(bool)]
# Out:
#              AEONTS.BK     ASK.BK     BAY.BK      BBL.BK   CHAYO.BK  \
# Date
# 2021-05-10  203.582214  32.944241  34.599052  115.794579  14.228763
# 2021-05-11  196.860138  36.116650  32.162495  115.308052  13.854321
# 2021-05-12  194.573914  32.456177  31.675184  113.848457  13.573491
# 2021-05-13  191.655304  32.212147  30.944220  114.334984  13.386272
# 2021-05-14  186.790955  34.652462  31.187876  112.388863  13.386272
# ...                ...        ...        ...         ...        ...
# 2021-10-06  188.250259  34.164398  32.072990  113.392334  11.047817
# 2021-10-07  192.141724  34.164398  32.566422  116.337585  11.141443
# 2021-10-08  190.682434  34.652462  32.566422  116.337585  11.047817
# 2021-10-11  189.223129  34.652462  32.319706  116.337585  10.860567
# 2021-10-12  189.709564  34.652462  32.319706  117.810219  10.860567
#
#                JMT.BK    KBANK.BK     KKP.BK     KTC.BK  MICRO.BK     MTC.BK  \
# Date
# ...

# %%
df
# Out:
#              AEONTS.BK     ASK.BK     BAY.BK      BBL.BK   CHAYO.BK  \
# Date
# 2018-01-03   92.578255  17.726864  35.356331  175.389221        NaN
# 2018-01-04   92.578255  17.875828  34.693398  175.389221        NaN
# 2018-01-05   93.025475  17.801344  40.438797  176.244751        NaN
# 2018-01-08   93.919960  17.726864  41.543686  177.100311        NaN
# 2018-01-09  107.337105  17.577898  40.659779  177.955856        NaN
# ...                ...        ...        ...         ...        ...
# 2021-10-06  188.250259  34.164398  32.072990  113.392334  11.047817
# 2021-10-07  192.141724  34.164398  32.566422  116.337585  11.141443
# 2021-10-08  190.682434  34.652462  32.566422  116.337585  11.047817
# 2021-10-11  189.223129  34.652462  32.319706  116.337585  10.860567
# 2021-10-12  189.709564  34.652462  32.319706  117.810219  10.860567
#
#                JMT.BK    KBANK.BK     KKP.BK     KTC.BK  MICRO.BK     MTC.BK  \
# Date
# ...

# %%
df.isnull()
# Out:
#             AEONTS.BK  ASK.BK  BAY.BK  BBL.BK  CHAYO.BK  JMT.BK  KBANK.BK  \
# Date
# 2018-01-03      False   False   False   False      True   False     False
# 2018-01-04      False   False   False   False      True   False     False
# 2018-01-05      False   False   False   False      True   False     False
# 2018-01-08      False   False   False   False      True   False     False
# 2018-01-09      False   False   False   False      True   False     False
# ...               ...     ...     ...     ...       ...     ...       ...
# 2021-10-06      False   False   False   False     False   False     False
# 2021-10-07      False   False   False   False     False   False     False
# 2021-10-08      False   False   False   False     False   False     False
# 2021-10-11      False   False   False   False     False   False     False
# 2021-10-12      False   False   False   False     False   False     False
#
#             KKP.BK  KTC.BK  MICRO.BK  MTC.BK  NCAP.BK  S11.BK  SAK.BK  \
# ...

# %%
~df.isnull()
# Out:
#             AEONTS.BK  ASK.BK  BAY.BK  BBL.BK  CHAYO.BK  JMT.BK  KBANK.BK  \
# Date
# 2018-01-03       True    True    True    True     False    True      True
# 2018-01-04       True    True    True    True     False    True      True
# 2018-01-05       True    True    True    True     False    True      True
# 2018-01-08       True    True    True    True     False    True      True
# 2018-01-09       True    True    True    True     False    True      True
# ...               ...     ...     ...     ...       ...     ...       ...
# 2021-10-06       True    True    True    True      True    True      True
# 2021-10-07       True    True    True    True      True    True      True
# 2021-10-08       True    True    True    True      True    True      True
# 2021-10-11       True    True    True    True      True    True      True
# 2021-10-12       True    True    True    True      True    True      True
#
#             KKP.BK  KTC.BK  MICRO.BK  MTC.BK  NCAP.BK  S11.BK  SAK.BK  \
# ...

# %%
df.isnull().sum(1)
# Out:
# Date
# 2018-01-03    5
# 2018-01-04    5
# 2018-01-05    5
# 2018-01-08    5
# 2018-01-09    5
#              ..
# 2021-10-06    0
# 2021-10-07    0
# 2021-10-08    0
# 2021-10-11    0
# 2021-10-12    0
# Length: 920, dtype: int64

# %%
~df.isnull().sum(1) #bitwise
# Out:
# Date
# 2018-01-03   -6
# 2018-01-04   -6
# 2018-01-05   -6
# 2018-01-08   -6
# 2018-01-09   -6
#              ..
# 2021-10-06   -1
# 2021-10-07   -1
# 2021-10-08   -1
# 2021-10-11   -1
# 2021-10-12   -1
# Length: 920, dtype: int64

# %%
df.isnull().sum(axis=0).astype(bool)
# Out:
# AEONTS.BK    False
# ASK.BK       False
# BAY.BK       False
# BBL.BK       False
# CHAYO.BK      True
# JMT.BK       False
# KBANK.BK     False
# KKP.BK       False
# KTC.BK       False
# MICRO.BK      True
# MTC.BK       False
# NCAP.BK       True
# S11.BK       False
# SAK.BK        True
# SAWAD.BK     False
# THANI.BK     False
# TIDLOR.BK     True
# TISCO.BK     False
# TK.BK        False
# TTB.BK       False
# dtype: bool

# %%
~df.isnull().sum(axis=1).astype(bool).tail(20)
# Out:
# Date
# 2021-09-14    True
# 2021-09-15    True
# 2021-09-16    True
# 2021-09-17    True
# 2021-09-20    True
# 2021-09-21    True
# 2021-09-22    True
# 2021-09-23    True
# 2021-09-27    True
# 2021-09-28    True
# 2021-09-29    True
# 2021-09-30    True
# 2021-10-01    True
# 2021-10-04    True
# 2021-10-05    True
# 2021-10-06    True
# 2021-10-07    True
# 2021-10-08    True
# 2021-10-11    True
# 2021-10-12    True
# dtype: bool

# %%
df.stack()
# Out:
# Date
# 2018-01-03  AEONTS.BK     92.578255
#             ASK.BK        17.726864
#             BAY.BK        35.356331
#             BBL.BK       175.389221
#             JMT.BK        13.175614
#                             ...
# 2021-10-12  THANI.BK       3.883196
#             TIDLOR.BK     32.481274
#             TISCO.BK      86.317085
#             TK.BK          8.645982
#             TTB.BK         1.126857
# Length: 15445, dtype: float64

# %%
df.stack().reset_index()
# Out:
#             Date    level_1           0
# 0     2018-01-03  AEONTS.BK   92.578255
# 1     2018-01-03     ASK.BK   17.726864
# 2     2018-01-03     BAY.BK   35.356331
# 3     2018-01-03     BBL.BK  175.389221
# 4     2018-01-03     JMT.BK   13.175614
# ...          ...        ...         ...
# 15440 2021-10-12   THANI.BK    3.883196
# 15441 2021-10-12  TIDLOR.BK   32.481274
# 15442 2021-10-12   TISCO.BK   86.317085
# 15443 2021-10-12      TK.BK    8.645982
# 15444 2021-10-12     TTB.BK    1.126857
#
# [15445 rows x 3 columns]

# %%
df.stack().groupby(level=0).head(1)
# Out:
# Date
# 2018-01-03  AEONTS.BK     92.578255
# 2018-01-04  AEONTS.BK     92.578255
# 2018-01-05  AEONTS.BK     93.025475
# 2018-01-08  AEONTS.BK     93.919960
# 2018-01-09  AEONTS.BK    107.337105
#                             ...
# 2021-10-06  AEONTS.BK    188.250259
# 2021-10-07  AEONTS.BK    192.141724
# 2021-10-08  AEONTS.BK    190.682434
# 2021-10-11  AEONTS.BK    189.223129
# 2021-10-12  AEONTS.BK    189.709564
# Length: 920, dtype: float64

# %%
df.stack().groupby(level=1).head(1)
# Out:
# Date
# 2018-01-03  AEONTS.BK     92.578255
#             ASK.BK        17.726864
#             BAY.BK        35.356331
#             BBL.BK       175.389221
#             JMT.BK        13.175614
#             KBANK.BK     208.472855
#             KKP.BK        56.134010
#             KTC.BK        16.831442
#             MTC.BK        38.350216
#             S11.BK         6.029596
#             SAWAD.BK      51.122288
#             THANI.BK       4.233280
#             TISCO.BK      61.536510
#             TK.BK         12.529217
#             TTB.BK         2.383078
# 2018-03-22  CHAYO.BK       1.638680
# 2020-10-01  MICRO.BK       5.326630
# 2020-11-09  NCAP.BK        3.060000
# 2020-12-08  SAK.BK         8.019594
# 2021-05-10  TIDLOR.BK     42.156548
# dtype: float64
