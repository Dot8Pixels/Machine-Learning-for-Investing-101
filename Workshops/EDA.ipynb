# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
data = yf.download("CL=F",start='2016-01-01', end='2021-10-01', period='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1446 entries, 2015-12-31 to 2021-09-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1446 non-null   float64
#  1   High       1446 non-null   float64
#  2   Low        1446 non-null   float64
#  3   Close      1446 non-null   float64
#  4   Adj Close  1446 non-null   float64
#  5   Volume     1446 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 79.1 KB

# %%
df = data.Close.copy()

# %%
df
# Out:
# Date
# 2015-12-31    37.040001
# 2016-01-04    36.759998
# 2016-01-05    35.970001
# 2016-01-06    33.970001
# 2016-01-07    33.270000
#                 ...
# 2021-09-24    73.980003
# 2021-09-27    75.449997
# 2021-09-28    75.290001
# 2021-09-29    74.830002
# 2021-09-30    75.029999
# Name: Close, Length: 1446, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
sns.lineplot(data=df)
plt.show()

# %%
daily_returns = df.pct_change()

# %%
daily_returns
# Out:
# Date
# 2015-12-31         NaN
# 2016-01-04   -0.007559
# 2016-01-05   -0.021491
# 2016-01-06   -0.055602
# 2016-01-07   -0.020606
#                 ...
# 2021-09-24    0.009277
# 2021-09-27    0.019870
# 2021-09-28   -0.002121
# 2021-09-29   -0.006110
# 2021-09-30    0.002673
# Name: Close, Length: 1446, dtype: float64

# %%
sns.displot(df)

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>
