# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("./Example Data/setsmart_example_ratios.xlsx", engine='openpyxl')

# %%
data
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    Date     Market     Symbol      Prior       Open
# 1     2021-09-30 00:00:00        SET        AOT         62      61.75
# 2     2021-09-29 00:00:00        SET        AOT         62         62
# 3     2021-09-28 00:00:00        SET        AOT      62.25      62.25
# 4     2021-09-27 00:00:00        SET        AOT       62.5       62.5
# ...                   ...        ...        ...        ...        ...
# 1396  2016-01-08 00:00:00        SET        AOT        337        339
# 1397  2016-01-07 00:00:00        SET        AOT        340        338
# 1398  2016-01-06 00:00:00        SET        AOT        340        340
# 1399  2016-01-05 00:00:00        SET        AOT        343        344
# 1400  2016-01-04 00:00:00        SET        AOT        346        349
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
data = pd.read_excel("./Example Data/setsmart_example_ratios.xlsx", 
                    engine='openpyxl',
                    header=1)

# %%
data
# Out:
#            Date Market Symbol   Prior    Open    High     Low   Close  Change  \
# 0    2021-09-30    SET    AOT   62.00   61.75   62.00   60.50   61.00   -1.00
# 1    2021-09-29    SET    AOT   62.00   62.00   62.75   61.75   62.00    0.00
# 2    2021-09-28    SET    AOT   62.25   62.25   62.75   61.50   62.00   -0.25
# 3    2021-09-27    SET    AOT   62.50   62.50   63.25   62.00   62.25   -0.25
# 4    2021-09-23    SET    AOT   62.25   62.25   63.00   62.25   62.50    0.25
# ...         ...    ...    ...     ...     ...     ...     ...     ...     ...
# 1395 2016-01-08    SET    AOT  337.00  339.00  341.00  336.00  338.00    1.00
# 1396 2016-01-07    SET    AOT  340.00  338.00  338.00  333.00  337.00   -3.00
# 1397 2016-01-06    SET    AOT  340.00  340.00  343.00  338.00  340.00    0.00
# 1398 2016-01-05    SET    AOT  343.00  344.00  345.00  339.00  340.00   -3.00
# 1399 2016-01-04    SET    AOT  346.00  349.00  351.00  339.00  343.00   -3.00
#
# ...

# %%
df = data[['Date', 'Prior', 'Open', 'High', 'Low', 'Close', '%Change', 'Market Cap', 'PE', 'PEG', 'PBV']].set_index('Date')

# %%
df.head()
# Out:
#             Prior   Open   High    Low  Close   %Change    Market Cap  PE  \
# Date
# 2021-09-30  62.00  61.75  62.00  60.50  61.00 -1.612903  871427700000 NaN
# 2021-09-29  62.00  62.00  62.75  61.75  62.00  0.000000  885713400000 NaN
# 2021-09-28  62.25  62.25  62.75  61.50  62.00 -0.401606  885713400000 NaN
# 2021-09-27  62.50  62.50  63.25  62.00  62.25 -0.400000  889284825000 NaN
# 2021-09-23  62.25  62.25  63.00  62.25  62.50  0.401606  892856250000 NaN
#
#             PEG   PBV
# Date
# 2021-09-30  NaN  7.42
# 2021-09-29  NaN  7.54
# 2021-09-28  NaN  7.54
# 2021-09-27  NaN  7.57
# 2021-09-23  NaN  7.60

# %%
df.loc['2020']
# Out:
#             Prior   Open   High    Low  Close   %Change     Market Cap  \
# Date
# 2020-12-30  62.50  62.75  63.25  61.50  62.25 -0.400000   889284825000
# 2020-12-29  61.50  61.50  63.25  61.25  62.50  1.626016   892856250000
# 2020-12-28  62.50  63.00  63.00  61.50  61.50 -1.600000   878570550000
# 2020-12-25  61.75  62.50  62.50  61.50  62.50  1.214575   892856250000
# 2020-12-24  61.25  61.00  62.00  60.25  61.75  0.816327   882141975000
# ...           ...    ...    ...    ...    ...       ...            ...
# 2020-01-08  73.75  72.25  73.00  72.00  73.00 -1.016949  1042856100000
# 2020-01-07  72.25  73.00  73.75  72.75  73.75  2.076125  1053570375000
# 2020-01-06  74.00  73.00  73.25  71.75  72.25 -2.364865  1032141825000
# 2020-01-03  75.25  74.75  74.75  73.75  74.00 -1.661130  1057141800000
# 2020-01-02  74.25  74.50  75.50  74.25  75.25  1.346801  1074998925000
#
#                 PE    PEG   PBV
# Date
# 2020-12-30  205.82  -2.49  6.25
# 2020-12-29  206.65  -2.50  6.28
# ...

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.PBV.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.PBV.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.PBV.hist(bins=50, grid=False)
# Out:
# <AxesSubplot:>
